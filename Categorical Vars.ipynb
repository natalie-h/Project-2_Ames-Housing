# %%
# Neighborhoods
# Neighborhood_Blueste -0.025195590254554926
# Neighborhood_BrDale -0.09527347259531159
# Neighborhood_BrkSide -0.13470271010647022
# Neighborhood_ClearCr 0.05261494440449314
# Neighborhood_CollgCr 0.08259000121133211
# Neighborhood_Crawfor 0.05855813062624967
# Neighborhood_Edwards -0.17668746528761092
# Neighborhood_Gilbert 0.024173214031369357
# Neighborhood_Greens 0.003507042355129271
# Neighborhood_GrnHill 0.03888920083467142
# Neighborhood_IDOTRR -0.18918282687989357
# Neighborhood_Landmrk -0.012383445025315278
# Neighborhood_MeadowV -0.11152391919492709
# Neighborhood_Mitchel -0.03543430320680783
# Neighborhood_NAmes -0.1891783889614976
# Neighborhood_NPkVill -0.04724635616299205
# Neighborhood_NWAmes 0.035104175564812316
# Neighborhood_NoRidge 0.2636341565564581
# Neighborhood_NridgHt 0.44906168441392064
# Neighborhood_OldTown -0.2082536380322654
# Neighborhood_SWISU -0.07415041405646619
# Neighborhood_Sawyer -0.13357355354711362
# Neighborhood_SawyerW 0.016877518056944457
# Neighborhood_Somerst 0.14943471057043348
# Neighborhood_StoneBr 0.25719880935922357
# Neighborhood_Timber 0.11424213456077925
# Neighborhood_Veenker 0.08329250854051162

# Streets:
# Street_Pave 0.06983056714841016
# Street_Grvl -0.06983056714841016

# Alleys:
# Alley_Grvl -0.15904590246429556
# Alley_Pave -0.0144445356144784

# Lot Shapes:
# Lot Shape_Reg -0.3058145658051542
# Lot Shape_IR1 0.27304290869548875
# Lot Shape_IR2 0.11007009977131521
# Lot Shape_IR3 0.009850933938037557

# Land Contours:
# Land Contour_Lvl -0.09148093117544202
# Land Contour_HLS 0.21095749423020757
# Land Contour_Bnk -0.09806541963075725
# Land Contour_Low 0.0330395370826179

# Utilities:
# Utilities_AllPub 0.03307577976460638
# Utilities_NoSeWa -0.012247470310393957
# Utilities_NoSewr -0.03451733022450688

# Lot Configs:
# Lot Config_Inside -0.08254356721039545
# Lot Config_Corner -0.004555348271795945
# Lot Config_CulDSac 0.16261785425234085
# Lot Config_FR2 -0.01473565499594687
# Lot Config_FR3 0.014391380127632511

# Land Slopes:
# Land Slope_Gtl -0.06274067369993094
# Land Slope_Mod 0.06204047555967415
# Land Slope_Sev 0.01163734168278861

# Condition 1s:
#     Condition 1_Norm 0.11118404951913972
# Condition 1_Feedr -0.1142587579938953
# Condition 1_Artery -0.12496783264227013
# Condition 1_RRAn -0.014887374598694136
# Condition 1_PosN 0.10696929089734628
# Condition 1_RRAe -0.053594559739916676
# Condition 1_PosA 0.0709909009173854
# Condition 1_RRNn 0.011474074727720199
# Condition 1_RRNe -0.0250324103548816

# Condition 2s
# Condition 2_Norm -0.009822004389212291
# Condition 2_Feedr -0.04843044879363775
# Condition 2_Artery -0.038926577709092774
# Condition 2_PosA 0.10109311748146112
# Condition 2_PosN 0.1035088525482365
# Condition 2_RRNn -0.033396222908903345
# Condition 2_RRAe 0.002389996299821099
# Condition 2_RRAn -0.012413361598643062

# Bldg Types
# Bldg Type_1Fam 0.10550079043144765
# Bldg Type_TwnhsE 0.062210511572846225
# Bldg Type_Duplex -0.10361713853433122
# Bldg Type_Twnhs -0.11383012803062868

# House Styles
# House Style_1Story -0.022174506356796835
# House Style_2Story 0.20232845122758106
# House Style_1.5Fin -0.19568204535543707
# House Style_SLvl -0.041994826067328184
# House Style_SFoyer -0.06402283921694304
# House Style_2.5Unf 0.010839859326154508
# House Style_1.5Unf -0.06678373829491994
# House Style_2.5Fin 0.042557314715211375

# Roof Styles
# Roof Style_Gable -0.24860455942691467
# Roof Style_Hip 0.26449021310732773
# Roof Style_Flat 0.010268929725445256
# Roof Style_Gambrel -0.041854857055064545
# Roof Style_Mansard -0.021264653087151166
# Roof Style_Shed 0.013160361050837184

# Roof Matls
# Roof Matl_CompShg -0.0691881572400356
# Roof Matl_Tar&Grv 0.007065808890643552
# Roof Matl_WdShngl 0.0985817479604053
# Roof Matl_WdShake 0.046216958624383166
# Roof Matl_Membran 0.016748654022222538
# Roof Matl_ClyTile -0.005974270334587503

# Exterior 1sts
# Exterior 1st_VinylSd 0.3416807462335144
# Exterior 1st_MetalSd -0.1496690377545636
# Exterior 1st_HdBoard -0.11415065268782593
# Exterior 1st_Wd Sdng -0.19158820619860195
# Exterior 1st_Plywood -0.038987904833371535
# Exterior 1st_CemntBd 0.16767615155498564
# Exterior 1st_BrkFace 0.026342401432260437
# Exterior 1st_WdShing -0.048801332078535105
# Exterior 1st_AsbShng -0.12630933038607453
# Exterior 1st_Stucco -0.06082084232904771
# Exterior 1st_BrkComm -0.024364056986407073
# Exterior 1st_CBlock -0.03477659337664416
# Exterior 1st_Stone 0.030396612278832932
# Exterior 1st_ImStucc 0.022464236222401745
# Exterior 1st_AsphShn -0.027616810251119776

# Exterior 2nds
# Exterior 2nd_VinylSd 0.33709302911509553
# Exterior 2nd_MetalSd -0.13915659466115782
# Exterior 2nd_HdBoard -0.10228718160200598
# Exterior 2nd_Wd Sdng -0.17282443271777712
# Exterior 2nd_Plywood -0.05939313495045803
# Exterior 2nd_CmentBd 0.1571590432293413
# Exterior 2nd_Wd Shng -0.06108752503398401
# Exterior 2nd_BrkFace 0.010759552431529592
# Exterior 2nd_ImStucc 0.0426822004795651
# Exterior 2nd_AsbShng -0.11037363181375273
# Exterior 2nd_Brk Cmn -0.04785827361129988
# Exterior 2nd_ImStucc 0.0426822004795651
# Exterior 2nd_Stone -0.024620775018487404
# Exterior 2nd_AsphShn -0.02382051659638262
# Exterior 2nd_CBlock -0.035269582829408744

# Mas Vnr Types
# Mas Vnr Type_None -0.4237209941713916
# Mas Vnr Type_BrkFace 0.25835518235243865
# Mas Vnr Type_Stone 0.31027941463245057
# Mas Vnr Type_BrkCmn -0.037215425546493104

# Exter Quals
# Exter Qual_TA -0.6001027500222534
# Exter Qual_Gd 0.4462882302081917
# Exter Qual_Ex 0.4941145296863707
# Exter Qual_Fa -0.13106320328145568

# Exter Conds
# Exter Cond_TA 0.12184680143547173
# Exter Cond_Gd -0.05963609801654416
# Exter Cond_Ex 0.04050964035254934
# Exter Cond_Fa -0.155861887760258
# Exter Cond_Po -0.05388486456579917

# Foundations
# Foundation_PConc 0.5287724598318825
# Foundation_CBlock -0.35524947690170366
# Foundation_BrkTil -0.22978031981739264
# Foundation_Slab -0.11901755605914074
# Foundation_Stone -0.023833923486347403
# Foundation_Wood -0.003028072618605392

# Bsmt Quals
# Bsmt Qual_TA -0.45673333667271865
# Bsmt Qual_Gd 0.22635707358410223
# Bsmt Qual_Ex 0.5868451658487448
# Bsmt Qual_Fa -0.16145472288585203
# Bsmt Qual_Po -0.025769701369354536

# Bsmt Conds
# Bsmt Cond_TA 0.09348228854377742
# Bsmt Cond_Gd 0.11437966438367726
# Bsmt Cond_Ex 0.006557351868317809
# Bsmt Cond_Fa -0.1434184611930723
# Bsmt Cond_Po -0.03579811508941351

# Bsmt Exposures
# Bsmt Exposure_No -0.2925993121260704
# Bsmt Exposure_Av 0.12537608998625158
# Bsmt Exposure_Gd 0.37732498074625664
# Bsmt Exposure_Mn 0.029487518566877213

# BsmtFin Type 1s
# BsmtFin Type 1_GLQ 0.46313781512771957
# BsmtFin Type 1_Unf -0.12442690029006329
# BsmtFin Type 1_ALQ -0.08792246754452217
# BsmtFin Type 1_BLQ -0.1299689935248034
# BsmtFin Type 1_Rec -0.15079606004864488
# BsmtFin Type 1_LwQ -0.08132609362624428

# BsmtFin Type 2s
# BsmtFin Type 2_GLQ 0.05360242954310603
# BsmtFin Type 2_Unf 0.11375487483352385
# BsmtFin Type 2_ALQ 0.011874909573004582
# BsmtFin Type 2_BLQ -0.0484028972552405
# BsmtFin Type 2_Rec -0.04295320235735769
# BsmtFin Type 2_LwQ -0.041951002879101924

# Heatings
# Heating_GasA 0.09398683769231506
# Heating_GasW -0.037772236212687695
# Heating_Wall -0.0713025022288855
# Heating_Grav -0.0725438842841591
# Heating_OthW -0.02195886760476515

# Heating QCs
# Heating QC_Ex 0.45297886270094606
# Heating QC_TA -0.34333562552430424
# Heating QC_Gd -0.1151493460646094
# Heating QC_Fa -0.14917392568000912
# Heating QC_Po -0.05430306691397665

# Central Airs
# Central Air_Y 0.2773186063067728
# Central Air_N -0.27731860630677274

# Electricals
# Electrical_SBrkr 0.25395771691296837
# Electrical_FuseA -0.20112447785205873
# Electrical_FuseF -0.1293208197587746
# Electrical_FuseP -0.07235389665405936
# Electrical_Mix -0.03190349690125418

# Kitchen Quals
# Kitchen Qual_TA -0.5406126897943634
# Kitchen Qual_Gd 0.3068069126458857
# Kitchen Qual_Ex 0.5512619160297748
# Kitchen Qual_Fa -0.15483884915424653

# Functionals
# Functional_Typ 0.11757655490806841
# Functional_Min1 -0.049278005713260416
# Functional_Min2 -0.05658844641934101
# Functional_Mod -0.050371723997841775
# Functional_Maj1 -0.017743165363395548
# Functional_Maj2 -0.0696412382846237
# Functional_Sev -0.033790614471115
# Functional_Sal -0.059110552765103686

# Fireplace Qus
# Fireplace Qu_Gd 0.3842127672241891
# Fireplace Qu_TA 0.14739785624558674
# Fireplace Qu_Fa -0.024203474287252922
# Fireplace Qu_Ex 0.2346588006331021
# Fireplace Qu_Po -0.06593723008674039

# Garage Types
# Garage Type_Attchd 0.3576024447548683
# Garage Type_Detchd -0.3701680335611649
# Garage Type_BuiltIn 0.22002520082889662
# Garage Type_Basment -0.05567497281661826
# Garage Type_2Types -0.02959354195072083
# Garage Type_CarPort -0.07193678758471847

# Garage Finishes
# Garage Finish_Unf -0.4319740657257324
# Garage Finish_RFn 0.1839177757968517
# Garage Finish_Fin 0.4233951906731777

# Garage Quals
# Garage Qual_TA 0.24966952183175872
# Garage Qual_Fa -0.16807592689871417
# Garage Qual_Gd 0.09688061862283877
# Garage Qual_Ex 0.028782114482651312
# Garage Qual_Po -0.04591815500912361

# Garage Conds
# Garage Cond_TA 0.2717653377330226
# Garage Cond_Fa -0.14313694002113864
# Garage Cond_Gd 0.026731443687298344
# Garage Cond_Ex -0.022649052838635556
# Garage Cond_Po -0.07228184992191129

# Paved Drives
# Paved Drive_Y 0.28913072004970136
# Paved Drive_N -0.2735471826873103
# Paved Drive_P -0.09069470648992604

# Pool QCs
# Pool QC_Gd 0.019567011080098683
# Pool QC_TA -0.01574720049993148
# Pool QC_Fa 0.01343777510373148
# Pool QC_Ex 0.03724110727652361

# Fences
# Fence_MnPrv -0.1503035418436473
# Fence_GdPrv -0.011531267991835735
# Fence_GdWo -0.10154868999356867
# Fence_MnWw -0.04087847965791962

# Misc Features
# Misc Feature_Shed -0.04734434237682261
# Misc Feature_Gar2 -0.019490654281223253
# Misc Feature_Othr -0.008822828056818785
# Misc Feature_Elev 0.0006753216397673355
# Misc Feature_TenC 0.019118529568638302

# Sale Types
# Sale Type_WD  -0.21158584142624226
# Sale Type_New 0.35741927853534905
# Sale Type_COD -0.10753774163317965
# Sale Type_ConLD -0.060400130418902305
# Sale Type_CWD 0.004601124676477984
# Sale Type_ConLI 0.019624682628607112
# Sale Type_ConLw -0.03546312770924838
# Sale Type_Con 0.03369345032175835
# Sale Type_Oth -0.03009441213545306
